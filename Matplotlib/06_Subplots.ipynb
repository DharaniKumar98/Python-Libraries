# %% [markdown]
# ## Visualisation in Python - Matplotlib

# %% [markdown]
# ### Subplots: Comparing the trend of sales across different regions

# %% [markdown]
# -  Plotting different categories in the same graph or next to each other
# -  Helps in comparing and summarising the information over multiple categories

# %%
# importing numpy and the pyplot package of matplotlib
import numpy as np
import matplotlib.pyplot as plt


# Data for sales made by the company across three regions over the years 2012 to 2015
years = np.array(['2012', '2013', '2014', '2015'])
sales_Africa = np.array([127187.27, 144480.70, 229068.79, 283036.44])
sales_Asia_Pacific = np.array([713658.22, 863983.97, 1092231.65, 1372784.40])
sales_Europe = np.array([540750.63, 717611.40, 848670.24, 1180303.95])

# %%
# Plotting the trend of sales in African region over the 4 years
# Check the array names before plotting to avoid error

fig , ax = plt.subplots()
ax.plot(years ,sales_Africa)


plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Plotting the trend of sales in all three regions over the 4 years using subplots

fig , ax = plt.subplots()


ax.plot(years ,sales_Africa , label = 'Arfica')

ax.plot(years ,sales_Asia_Pacific ,label = 'Apac' )

ax.plot(years ,sales_Europe , label = 'Eur')

plt.legend()

plt.show()

# %% [markdown]
# #### Subplots with a shared y-axis

# %%
# Plotting three charts with a shared y-axis

fig , (ax1,ax2,ax3) = plt.subplots(1,3 ,sharey=True)


subplot_1, = ax1.plot(years ,sales_Africa , label = 'Arfica')

subplot_2, = ax2.plot(years ,sales_Asia_Pacific ,label = 'Apac' )

subplot_3, = ax3.plot(years ,sales_Europe , label = 'Eur')

# ax.legend([subplot_1, subplot_2 ,subplot_3], ['Arfica', 'Apac' , 'Eur'])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Dell\Desktop\Matplotlib\06_Subplots.ipynb Cell 8' in <cell line: 12>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Matplotlib/06_Subplots.ipynb#ch0000007?line=7'>8</a> subplot_2, = ax2.plot(years ,sales_Asia_Pacific ,label = 'Apac' )
#      <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Matplotlib/06_Subplots.ipynb#ch0000007?line=9'>10</a> subplot_3, = ax3.plot(years ,sales_Europe , label = 'Eur')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Matplotlib/06_Subplots.ipynb#ch0000007?line=11'>12</a> ax.legend([subplot_1, subplot_2 ,subplot_3], ['Arfica', 'Apac' , 'Eur'])
#      <a href='vscode-notebook-cell:/c%3A/Users/Dell/Desktop/Matplotlib/06_Subplots.ipynb#ch0000007?line=13'>14</a> plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'legend'

# %%
# Plotting three charts with a shared y-axis

fig , (ax1,ax2,ax3) = plt.subplots(1,3 ,sharey=True)


ax1.plot(years ,sales_Africa)
ax1.set_xlabel('Africa')

ax2.plot(years ,sales_Asia_Pacific)
ax2.set_xlabel('Apac')

ax3.plot(years ,sales_Europe )
ax3.set_xlabel('Eur')

# ax.legend([subplot_1, subplot_2 ,subplot_3], ['Arfica', 'Apac' , 'Eur'])

plt.show()

# %% [markdown]
# Create a figure and a set of subplots.
#
# matplotlib.pyplot.subplots(nrows=1, ncols=1, *, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)

# %%
# First create some toy data:
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)

# Create just a figure and only one subplot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Simple plot')

# Create two subplots and unpack the output array immediately
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)

# Create four polar axes and access them through the returned array
fig, axs = plt.subplots(2, 2, subplot_kw=dict(projection="polar"))
axs[0, 0].plot(x, y)
axs[1, 1].scatter(x, y)

# Share a X axis with each column of subplots
plt.subplots(2, 2, sharex='col')

# Share a Y axis with each row of subplots
plt.subplots(2, 2, sharey='row')

# Share both X and Y axes with all subplots
plt.subplots(2, 2, sharex='all', sharey='all')

# Note that this is the same as
plt.subplots(2, 2, sharex=True, sharey=True)

# Create figure number 10 with a single subplot
# and clears it if it already exists.
fig, ax = plt.subplots(num=10, clear=True)
